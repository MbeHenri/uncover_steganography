# %% [markdown]
# # Utilisation des méthodes

# %% [markdown]
# ## Méthode cis_pdir : `Coverless image steganography using partial-duplicate image retrieval`

# %% [markdown]
# ### Construction de la structure d'indexage inversée

# %% [markdown]
# Nous avons utilisé une base de `10` images

# %%
from src.cis_pdir.build_indexdb import construct_indexfiles


result = construct_indexfiles(
    input_path_images="./images", Pw=40, Ph=30, n=4, m=3, K=3, L=10
)
# Out:
# /home/mbe/anaconda3/lib/python3.10/site-packages/sklearn/base.py:1351: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/mbe/anaconda3/lib/python3.10/site-packages/sklearn/base.py:1351: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/mbe/anaconda3/lib/python3.10/site-packages/sklearn/base.py:1351: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/mbe/anaconda3/lib/python3.10/site-packages/sklearn/base.py:1351: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# ...

# %% [markdown]
# ### Masquage de l'image secrète

# %%
from src.cis_pdir.hinding import hinding


hinding("./test.jpg")

# %%
from src.utils.functions import preprocessing


preprocessing("./test.jpg")
# Out:
# <PIL.Image.Image image mode=L size=640x480>

# %% [markdown]
# ### Extraction de l'image secrète

# %% [markdown]
# Cette étape vise à reconstruire l'image secrete approximativement en utilisant un ensemble d'images naturelles en entrée.
# Celà en retrouvant les blocs partieles des ses patchs dans l'ensemble des images naturelles, en utilisant leurs positions sauvegardé. puis les replacer dans l'image finale.

# %%
from src.cis_pdir.extracting import extracting


extracting(path_imgs="./send_imgs")
# Out:
# <PIL.Image.Image image mode=L size=640x480>
