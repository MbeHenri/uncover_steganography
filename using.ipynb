# %% [markdown]
# # Utilisation des méthodes

# %% [markdown]
# ## Méthode `CIS_PDIR` : Coverless image steganography using partial-duplicate image retrieval

# %% [markdown]
# ### Construction de la structure d'indexage inversée

# %% [markdown]
# Nous avons utilisé une base de `10` images

# %%
from src.cis_pdir.build_indexdb import construct_indexfiles

Pw = 40
Ph = 30
n = 2
m = 2
K = 2
L = 10
result = construct_indexfiles(
    input_path_images="./images", Pw=Pw, Ph=Ph, n=n, m=m, K=K, L=L
)
# Out:
# /home/mbe/anaconda3/lib/python3.10/site-packages/sklearn/base.py:1351: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (2). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/mbe/anaconda3/lib/python3.10/site-packages/sklearn/base.py:1351: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (2). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/mbe/anaconda3/lib/python3.10/site-packages/sklearn/base.py:1351: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (2). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/mbe/anaconda3/lib/python3.10/site-packages/sklearn/base.py:1351: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (2). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# ...

# %% [markdown]
# ### Masquage de l'image secrète

# %%
from src.cis_pdir.hide import hide

Iw = 640
Ih = 480
hide("./test.jpg", Ih=Ih, Iw=Iw)

# %%
from src.utils.functions import preprocessing

preprocessing("./test.jpg", Iw=Iw, Ih=Ih)
# Out:
# <PIL.Image.Image image mode=L size=640x480>

# %% [markdown]
# ### Extraction de l'image secrète

# %%
from src.cis_pdir.extract import extract

extract(path_imgs="./send_imgs")
# Out:
# <PIL.Image.Image image mode=L size=640x480>

# %% [markdown]
# ## Méthode `HCCIH` : Towards a high capacity coverless information hiding approach

# %% [markdown]
# ### Masquage du méssage

# %%
msg = "Bonjour à tous, je suis MBE MINDJANA, un dévellopeur pationné"
msg
# Out:
# 'Bonjour à tous, je suis MBE MINDJANA, un dévellopeur pationné'

# %%
W = 512
H = 512
preprocessing("./test.jpg", Iw=W, Ih=H)
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
from src.hccih.hide import hide

hide("./test.jpg", msg, W=W, H=H)

# %% [markdown]
# ### Extraction du méssage

# %%
from src.hccih.extract import extract

res_msg = extract("./test.jpg", unknow_car="*")
res_msg
# Out:
# 'Bonjour à tou*, je *ui* MBE MINDJANA, un dévellopeur p*tionné'
